# %%
#Imports
import pandas as pd
import numpy as np

#Load data
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"

#basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
#ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)
#akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %% [markdown]
# Basics Data Clean

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
basics.replace({'\\N':np.nan},inplace=True)
basics
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10006912  tt9916848  tvEpisode              Episode #3.17
# 10006913  tt9916850  tvEpisode              Episode #3.19
# 10006914  tt9916852  tvEpisode              Episode #3.20
# 10006915  tt9916856      short                   The Wind
# 10006916  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894     NaN              1
# 1            Le clown et ses chiens       0      1892     NaN              5
# ...

# %%
basics['primaryTitle'].isna().sum()
# Out:
# 0

# %%
basics = basics.dropna(subset= ["primaryTitle"])

# %%
basics['runtimeMinutes'].isna().sum()
# Out:
# 0

# %%
basics['genres'].isna().sum()
# Out:
# 0

# %%
basics = basics.dropna(subset=["runtimeMinutes", "genres"])

# %%
movies = basics["titleType"] == 'movie'

# %%
movies_filter = basics[movies]
movies_filter
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# 672       tt0000679     movie
# ...             ...       ...
# 10006767  tt9916538     movie
# 10006808  tt9916622     movie
# 10006835  tt9916680     movie
# 10006857  tt9916730     movie
# 10006867  tt9916754     movie
#
#                                                primaryTitle  \
# 8                                                Miss Jerry
# 144                           The Corbett-Fitzsimmons Fight
# 570                             The Story of the Kelly Gang
# 587                                        The Prodigal Son
# 672                          The Fairylogue and Radio-Plays
# ...                                                     ...
# 10006767                                Kuambil Lagi Hatiku
# 10006808        Rodolpho Teóphilo - O Legado de um Pioneiro
# ...

# %%
movies_filter['startYear'] = movies_filter['startYear'].astype(float)
# Out:
# /var/folders/ft/7m67_jrd7g37chfbmcdcrf8h0000gn/T/ipykernel_48486/1341746310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_filter['startYear'] = movies_filter['startYear'].astype(float)

# %%
movies_filter.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult            object
# startYear         float64
# endYear            object
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
year = movies_filter['startYear'] >= 2000.0 
years = movies_filter['startYear'] <= 2021.0

# %%
filtered_combined = year & years

# %%
movie_years = movies_filter[filtered_combined]
movie_years
# Out:
#              tconst titleType  \
# 13082     tt0013274     movie
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# 67666     tt0069049     movie
# 86793     tt0088751     movie
# ...             ...       ...
# 10006767  tt9916538     movie
# 10006808  tt9916622     movie
# 10006835  tt9916680     movie
# 10006857  tt9916730     movie
# 10006867  tt9916754     movie
#
#                                                primaryTitle  \
# 13082                           Istoriya grazhdanskoy voyny
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# 67666                            The Other Side of the Wind
# 86793                                     The Naked Monster
# ...                                                     ...
# 10006767                                Kuambil Lagi Hatiku
# 10006808        Rodolpho Teóphilo - O Legado de um Pioneiro
# ...

# %%
is_documentary = movie_years['genres'].str.contains('documentary',case=False)
years_filtered = movie_years[~is_documentary]

# %% [markdown]
# AKAs Data Clean

# %%
akas.replace({'\\N':np.nan},inplace=True)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
region = akas['region'] == 'US'

# %%
akas = akas[region]
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 36543429  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 36543499  tt9916620         1                          The Copeland Case
# 36543588  tt9916702         1              Loving London: The Playground
# 36543631  tt9916756         1                   Pretty Pretty Black Girl
# 36543647  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# ...

# %% [markdown]
# Ratings Data Clean

# %%
ratings.replace({'\\N':np.nan},inplace=True)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1986
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1847
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2629

# %%
keepers =ratings['tconst'].isin(akas['titleId'])

# %%
ratings = ratings[keepers]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1986
# 1        tt0000002            5.8       265
# 4        tt0000005            6.2      2629
# 5        tt0000006            5.1       182
# 6        tt0000007            5.4       824
# ...            ...            ...       ...
# 1329761  tt9916200            8.1       231
# 1329762  tt9916204            8.2       264
# 1329769  tt9916348            8.3        18
# 1329770  tt9916362            6.4      5417
# 1329775  tt9916428            3.8        14
#
# [503509 rows x 3 columns]

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['.title_akas.csv.gz.icloud',
#  '.title_basics.csv.gz.icloud',
#  '.title_ratings.csv.gz.icloud']

# %%
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
