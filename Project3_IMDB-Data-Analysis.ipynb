# %%
#Imports
import pandas as pd
import numpy as np

#Load data
#basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
#ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
#akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"

#basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
#ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)
#akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %% [markdown]
# Basics Data Clean

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
basics.replace({'\\N':np.nan},inplace=True)

# %%
basics['runtimeMinutes'].dropna(inplace=True)

# %%
basics1 = basics[basics['titleType'].str.contains('short|tvShort|tvMovie|tvSeries|tvEpisode|tvMiniSeries|tvSpecial|video|videoGame|tvPilot')==False]

# %%
basics1.head()
# Out:
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 144  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 498  tt0000502     movie                       Bohemios
# 570  tt0000574     movie    The Story of the Kelly Gang
# 587  tt0000591     movie               The Prodigal Son
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry       0      1894     NaN             45
# 144  The Corbett-Fitzsimmons Fight       0      1897     NaN            100
# 498                       Bohemios       0      1905     NaN            100
# 570    The Story of the Kelly Gang       0      1906     NaN             70
# 587              L'enfant prodigue       0      1907     NaN             90
#
#                          genres
# 8                       Romance
# 144      Documentary,News,Sport
# 498                         NaN
# 570  Action,Adventure,Biography
# ...

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics1['tconst'].isin(akas['titleId'])
keepers
# Out:
# 8          True
# 144        True
# 498        True
# 570        True
# 587        True
#            ...
# 9968507    True
# 9968534    True
# 9968546    True
# 9968556    True
# 9968566    True
# Name: tconst, Length: 649516, dtype: bool

# %%
basics1 = basics1[keepers]
basics1
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 498      tt0000502     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# ...            ...       ...
# 9968507  tt9916622     movie
# 9968534  tt9916680     movie
# 9968546  tt9916706     movie
# 9968556  tt9916730     movie
# 9968566  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# ...                                                    ...
# 9968507        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9968534  De la ilusión al desconcierto: cine colombiano...
# 9968546                                    Dankyavar Danka
# ...

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics1['genres'].str.contains('documentary',case=False)
basics1 = basics1[~is_documentary]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [23], line 3
#       1 # Exclude movies that are included in the documentary category.
#       2 is_documentary = basics1['genres'].str.contains('documentary',case=False)
# ----> 3 basics1 = basics1[~is_documentary]
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/generic.py:1522, in NDFrame.__invert__(self)
#    1518 if not self.size:
#    1519     # inv fails with 0 len
#    1520     return self
# -> 1522 new_data = self._mgr.apply(operator.invert)
#    1523 return self._constructor(new_data).__finalize__(self, method="__invert__")
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/internals/managers.py:350, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     348 try:
#     349     if callable(f):
# ...

# %% [markdown]
# AKAs Data Clean

# %%
akas.replace({'\\N':np.nan},inplace=True)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
keepers2 =akas['tconst'].isin(akas['titleId'])
keepers2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tconst'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
akas = akas[keepers2]
akas

# %% [markdown]
# Ratings Data Clean

# %%
ratings.replace({'\\N':np.nan},inplace=True)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1982
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1840
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2625

# %%
keepers3 =ratings['tconst'].isin(akas['titleId'])
keepers3
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1324795     True
# 1324796     True
# 1324797    False
# 1324798    False
# 1324799    False
# Name: tconst, Length: 1324800, dtype: bool

# %%
ratings = ratings[keepers3]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1982
# 1        tt0000002            5.8       265
# 2        tt0000003            6.5      1840
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2625
# ...            ...            ...       ...
# 1324777  tt9916460            9.4        18
# 1324781  tt9916538            8.6         7
# 1324782  tt9916544            6.8        64
# 1324795  tt9916730            8.3        10
# 1324796  tt9916766            7.0        21
#
# [989299 rows x 3 columns]

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# []

# %%
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
